# %%
import pandas as pd

df = pd.read_csv("input-pmdcmd-gdp.csv")
df[:5]
# Out:
#    Value  Period Reference Area Industry Section  \
# 0   97.9  2012.0     North East              A_T
# 1   91.0  2012.0     North East                A
# 2  102.8  2012.0     North East              B_E
# 3  161.5  2012.0     North East                B
# 4  102.7  2012.0     North East                C
#
#              Industry Section Label      Measure Type              Unit
# 0                             Total  Indices 2016=100  Indices 2016=100
# 1  Agriculture, Foresty and fishing  Indices 2016=100  Indices 2016=100
# 2       Total production industries  Indices 2016=100  Indices 2016=100
# 3                Mining & quarrying  Indices 2016=100  Indices 2016=100
# 4                     Manufacturing  Indices 2016=100  Indices 2016=100

# %%
df = pd.read_csv("output-cmd-regional-gdp-by-year-time-series-v3.csv")
df[:5]
# Out:
#     V4_1 Data Marking  calendar-years  Time nuts      Geography  \
# 0   88.4          NaN            2012  2012  UKK     South West
# 1  204.2          NaN            2013  2013  UKC     North East
# 2  100.5          NaN            2017  2017  UKC     North East
# 3   90.4          NaN            2014  2014  UKF  East Midlands
# 4    2.8          NaN            2017  2017  UKI         London
#
#   sic-unofficial UnofficialStandardIndustrialClassification type-of-prices  \
# 0              J          J : Information and communication            cvm
# 1              B                   B : Mining and quarrying            cvm
# 2           G--T                      G-T : Services sector            cvm
# 3              F                           F : Construction            cvm
# 4              P                              P : Education            cvm
#
#                    Prices quarterly-index-and-growth-rate          GrowthRate
# ...

# %%
df= df.drop("Data Marking", axis=1)
df
# Out:
#        V4_1  calendar-years  Time nuts        Geography sic-unofficial  \
# 0      88.4            2012  2012  UKK       South West              J
# 1     204.2            2013  2013  UKC       North East              B
# 2     100.5            2017  2017  UKC       North East           G--T
# 3      90.4            2014  2014  UKF    East Midlands              F
# 4       2.8            2017  2017  UKI           London              P
# ...     ...             ...   ...  ...              ...            ...
# 4409  121.6            2015  2015  UKZ      Extra-regio           G--T
# 4412    0.9            2015  2015  UKH  East of England              R
# 4413    3.6            2018  2018  UKD       North West              I
# 4414    6.1            2015  2015  UKI           London              R
# 4415  102.1            2018  2018  UKL            Wales           G--T
#
#          UnofficialStandardIndustrialClassification type-of-prices  \
# ...

# %%
df["V4_1"]
# Out:
# 0        88.4
# 1       204.2
# 2       100.5
# 3        90.4
# 4         2.8
#         ...
# 4409    121.6
# 4412      0.9
# 4413      3.6
# 4414      6.1
# 4415    102.1
# Name: V4_1, Length: 3870, dtype: float64

# %%
df.to_csv("output-cmd-regional-gdp-by-year-time-series-v3.csv", index=False)
