# %%
import pandas as pd

df = pd.read_csv("input-pmdcmd-gdp.csv")
df[:10]
# Out:
#       Period                                     Reference Area  \
# 0  year/2012                http://data.europa.eu/nuts/code/UKC
# 1  year/2012                http://data.europa.eu/nuts/code/UKD
# 2  year/2012                http://data.europa.eu/nuts/code/UKE
# 3  year/2012                http://data.europa.eu/nuts/code/UKF
# 4  year/2012                http://data.europa.eu/nuts/code/UKG
# 5  year/2012                http://data.europa.eu/nuts/code/UKH
# 6  year/2012                http://data.europa.eu/nuts/code/UKI
# 7  year/2012                http://data.europa.eu/nuts/code/UKJ
# 8  year/2012                http://data.europa.eu/nuts/code/UKK
# 9  year/2012  http://statistics.data.gov.uk/id/statistical-g...
#
#   Industry Section  Measure Type     Unit      Value
# 0              a_t  gdp-from-gva  indices  97.916263
# 1              a_t  gdp-from-gva  indices  92.315793
# 2              a_t  gdp-from-gva  indices  95.050427
# ...

# %%
df["Reference Area"] = df["Reference Area"].map(lambda x: x.split("/")[-1])
df[:10]

df["Period"] = df["Period"].map(lambda x: x.split("/")[-1])
df[:10]
# Out:
#   Period Reference Area Industry Section  Measure Type     Unit      Value
# 0   2012            UKC              a_t  gdp-from-gva  indices  97.916263
# 1   2012            UKD              a_t  gdp-from-gva  indices  92.315793
# 2   2012            UKE              a_t  gdp-from-gva  indices  95.050427
# 3   2012            UKF              a_t  gdp-from-gva  indices  92.477318
# 4   2012            UKG              a_t  gdp-from-gva  indices  89.813255
# 5   2012            UKH              a_t  gdp-from-gva  indices  89.626843
# 6   2012            UKI              a_t  gdp-from-gva  indices  87.837338
# 7   2012            UKJ              a_t  gdp-from-gva  indices  92.545869
# 8   2012            UKK              a_t  gdp-from-gva  indices  92.796948
# 9   2012      E92000001              a_t  gdp-from-gva  indices  91.098020

# %%
df.to_csv('input-pmdcmd-gdp.csv', index=False)
